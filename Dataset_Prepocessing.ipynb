# %% [markdown]
# <a href="https://colab.research.google.com/github/ElieB-1012/SpoilMe_GPT_3/blob/master/Dataset_Prepocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SpoilMe

# %% [markdown]
# In this Google Colab notebook, I import two datasets: one obtained from Kaggle and the other derived directly from the MooviePooper website using data scraping techniques. I perform preprocessing on the dataset to prepare it for fine-tuning.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# "Action Archives - MoviePooper full.csv" is the dataset that we scrapped with Octoparse.
#
# "IMDB Kaggle Dataset.json" is the dataset that we find from Kaggle.

# %%
df = pd.read_csv('Action Archives - MoviePooper full.csv')
df1 = pd.read_json('IMDB Kaggle Dataset.json')

# %% [markdown]
# Overview of the two dataset.

# %%
df.head()
# Out:
#                               Title  \
# 0                          +1(2013)
# 1                          10(1979)
# 2         10 Cloverfield Lane(2016)
# 3  10 Things I Hate About You(1999)
# 4              10 to Midnight(1983)
#
#                                              Spoiler
# 0  Short Version:\nDavid #1 kills Jill #1 with a ...
# 1                                                NaN
# 2  Howard (John Goodman) is truly hiding from a r...
# 3  Kat (Julia Stiles) reveals to Bianca (Larisa O...
# 4  Frustrated that he cannot get a confession fro...

# %%
df1.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1  tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2  tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
# 3  tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 4  tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
#
#                          genre  rating release_date  \
# 0           [Action, Thriller]     6.9   1992-06-05
# 1                     [Comedy]     6.6   2013-11-01
# 2            [Comedy, Romance]     6.7   2002-04-11
# 3  [Adventure, Drama, Western]     8.3   1948-01-24
# 4     [Comedy, Drama, Romance]     7.3   1999-05-07
#
#                                        plot_synopsis  \
# 0  Jack Ryan (Ford) is on a "working vacation" in...
# 1  Four boys around the age of 10 are friends in ...
# 2
# 3  Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 4  Jim McAllister (Matthew Broderick) is a much-a...
#
#                               title
# 0                     Patriot Games
# 1                        Last Vegas
# 2           Wet Hot American Summer
# 3  The Treasure of the Sierra Madre
# 4                          Election

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# In order to facilitate the merging process between the two datasets, we identified the need for a shared column. Consequently, we utilized the "Title" column as a common identifier for merging the datasets together.

# %%
df1.rename(columns = {'title':'Title'}, inplace = True)

# %% [markdown]
# In the "Title" column of the dataset containing spoilers, there were instances where the film release years were included. We had to remove the release years from the titles in order to successfully merge the datasets.

# %%
df['Title'] = df['Title'].str.split('(').str[0]

# %%
df.head()
# Out:
#                         Title  \
# 0                          +1
# 1                          10
# 2         10 Cloverfield Lane
# 3  10 Things I Hate About You
# 4              10 to Midnight
#
#                                              Spoiler
# 0  Short Version:\nDavid #1 kills Jill #1 with a ...
# 1                                                NaN
# 2  Howard (John Goodman) is truly hiding from a r...
# 3  Kat (Julia Stiles) reveals to Bianca (Larisa O...
# 4  Frustrated that he cannot get a confession fro...

# %% [markdown]
# Merge on "Title" column.

# %%
df2 = pd.merge(df1, df, on = 'Title')

# %%
df2.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1  tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2  tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
# 3  tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 4  tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
#
#                          genre  rating release_date  \
# 0           [Action, Thriller]     6.9   1992-06-05
# 1                     [Comedy]     6.6   2013-11-01
# 2            [Comedy, Romance]     6.7   2002-04-11
# 3  [Adventure, Drama, Western]     8.3   1948-01-24
# 4     [Comedy, Drama, Romance]     7.3   1999-05-07
#
#                                        plot_synopsis  \
# 0  Jack Ryan (Ford) is on a "working vacation" in...
# 1  Four boys around the age of 10 are friends in ...
# 2
# 3  Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 4  Jim McAllister (Matthew Broderick) is a much-a...
#
#                               Title  \
# 0                     Patriot Games
# 1                        Last Vegas
# 2           Wet Hot American Summer
# 3  The Treasure of the Sierra Madre
# 4                          Election
#
#                                              Spoiler
# 0  Ryan (Harrison Ford) manages to get his own fa...
# 1  Billy (Michael Douglas) is getting married for...
# 2  Beth (Janeane Garofalo) and Henry (David Hyde ...
# 3  The Treasure of the Sierra Madre\r\nAfter Fred...
# 4  Short version:\nTracy Flick wins the school el...

# %% [markdown]
# Create a Dataframe with only relevant column

# %%
df3 = df2[['Title', 'plot_summary','plot_synopsis','Spoiler']]

# %% [markdown]
# Data Cleaning

# %%
df3.replace('\n', ' ')
# Out:
#                                  Title  \
# 0                        Patriot Games
# 1                           Last Vegas
# 2              Wet Hot American Summer
# 3     The Treasure of the Sierra Madre
# 4                             Election
# ...                                ...
# 1151                             Dogma
# 1152    The Boy in the Striped Pajamas
# 1153              The Butterfly Effect
# 1154                             Shame
# 1155                           Dunkirk
#
#                                            plot_summary  \
# 0     Former CIA analyst, Jack Ryan is in England wi...
# 1     Billy (Michael Douglas), Paddy (Robert De Niro...
# 2     The setting is Camp Firewood, the year 1981. I...
# 3     Fred C. Dobbs and Bob Curtin, both down on the...
# 4     Tracy Flick is running unopposed for this year...
# ...                                                 ...
# 1151  An abortion clinic worker with a special herit...
# 1152  Young Bruno lives a wealthy lifestyle in prewa...
# 1153  Evan Treborn grows up in a small town with his...
# 1154  Brandon is a 30-something man living in New Yo...
# 1155  Evacuation of Allied soldiers from the British...
#
#                                           plot_synopsis  \
# 0     Jack Ryan (Ford) is on a "working vacation" in...
# 1     Four boys around the age of 10 are friends in ...
# 2
# 3     Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 4     Jim McAllister (Matthew Broderick) is a much-a...
# ...                                                 ...
# 1151  The film opens with a homeless man (Bud Cort) ...
# 1152
# 1153  In the year 1998, Evan Treborn (Ashton Kutcher...
# 1154  Brandon (Michael Fassbender) is a successful, ...
# 1155  The film alternates between three different pe...
#
#                                                 Spoiler
# 0     Ryan (Harrison Ford) manages to get his own fa...
# 1     Billy (Michael Douglas) is getting married for...
# 2     Beth (Janeane Garofalo) and Henry (David Hyde ...
# 3     The Treasure of the Sierra Madre\r\nAfter Fred...
# 4     Short version:\nTracy Flick wins the school el...
# ...                                                 ...
# 1151  Dogma\r\nThe comatose homeless man was God all...
# 1152  The “farm” is a Nazi death camp which Bruno’s ...
# 1153  The Butterfly Effect\r\nSeveral folks have wri...
# 1154  Short Ending:\nBrandon Sullivan is a self-loat...
# 1155  POOPER:\nThe evacuation of Dunkirk is a succes...
#
# [1156 rows x 4 columns]

# %%
df3['Spoiler'] = df3['Spoiler'].str.replace('\n', ' ')
df3['Spoiler'] = df3['Spoiler'].str.replace('\r', ' ')
# Out:
# <ipython-input-31-5d783583c7e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Spoiler'] = df3['Spoiler'].str.replace('\n', ' ')
# <ipython-input-31-5d783583c7e5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Spoiler'] = df3['Spoiler'].str.replace('\r', ' ')

# %%
df3.dropna(inplace=True)
# Out:
# <ipython-input-32-1cb041b5c165>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(inplace=True)

# %%
df3
# Out:
#                                  Title  \
# 0                        Patriot Games
# 1                           Last Vegas
# 2              Wet Hot American Summer
# 3     The Treasure of the Sierra Madre
# 4                             Election
# ...                                ...
# 1151                             Dogma
# 1152    The Boy in the Striped Pajamas
# 1153              The Butterfly Effect
# 1154                             Shame
# 1155                           Dunkirk
#
#                                            plot_summary  \
# 0     Former CIA analyst, Jack Ryan is in England wi...
# 1     Billy (Michael Douglas), Paddy (Robert De Niro...
# 2     The setting is Camp Firewood, the year 1981. I...
# 3     Fred C. Dobbs and Bob Curtin, both down on the...
# 4     Tracy Flick is running unopposed for this year...
# ...                                                 ...
# 1151  An abortion clinic worker with a special herit...
# 1152  Young Bruno lives a wealthy lifestyle in prewa...
# 1153  Evan Treborn grows up in a small town with his...
# 1154  Brandon is a 30-something man living in New Yo...
# 1155  Evacuation of Allied soldiers from the British...
#
#                                           plot_synopsis  \
# 0     Jack Ryan (Ford) is on a "working vacation" in...
# 1     Four boys around the age of 10 are friends in ...
# 2
# 3     Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 4     Jim McAllister (Matthew Broderick) is a much-a...
# ...                                                 ...
# 1151  The film opens with a homeless man (Bud Cort) ...
# 1152
# 1153  In the year 1998, Evan Treborn (Ashton Kutcher...
# 1154  Brandon (Michael Fassbender) is a successful, ...
# 1155  The film alternates between three different pe...
#
#                                                 Spoiler
# 0     Ryan (Harrison Ford) manages to get his own fa...
# 1     Billy (Michael Douglas) is getting married for...
# 2     Beth (Janeane Garofalo) and Henry (David Hyde ...
# 3     The Treasure of the Sierra Madre  After Fred C...
# 4     Short version: Tracy Flick wins the school ele...
# ...                                                 ...
# 1151  Dogma  The comatose homeless man was God all a...
# 1152  The “farm” is a Nazi death camp which Bruno’s ...
# 1153  The Butterfly Effect  Several folks have writt...
# 1154  Short Ending: Brandon Sullivan is a self-loath...
# 1155  POOPER: The evacuation of Dunkirk is a success...
#
# [1141 rows x 4 columns]

# %%
df3 = df3[df3['Spoiler'].str.len() >= 50]

# %%
df3.sort_values(by='Title', inplace=True)
df3 = df3.reset_index(drop=True)
df3.drop(columns=['plot_synopsis'], inplace=True)
df3.rename(columns = {'plot_summary':'Synopsis'}, inplace = True)
df3
# Out:
# <ipython-input-35-608e87a932fb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by='Title', inplace=True)
#                           Title  \
# 0    10 Things I Hate About You
# 1                  12 Angry Men
# 2                    12 Monkeys
# 3              12 Years a Slave
# 4                     127 Hours
# ..                          ...
# 991            Zero Dark Thirty
# 992                      Zodiac
# 993                  Zombieland
# 994                   Zoolander
# 995                    Zootopia
#
#                                               Synopsis  \
# 0    Adapted from William Shakespeare's play "The T...
# 1    The defense and the prosecution have rested an...
# 2    An unknown and lethal virus has wiped out five...
# 3    Based on an incredible true story of one man's...
# 4    127 Hours is the true story of mountain climbe...
# ..                                                 ...
# 991  Maya is a CIA operative whose first experience...
# 992  A serial killer in the San Francisco Bay Area ...
# 993  Searching for family. In the early twenty-firs...
# 994  Derek Zoolander is VH1's three time male model...
# 995  From the largest elephant to the smallest shre...
#
#                                                Spoiler
# 0    Kat (Julia Stiles) reveals to Bianca (Larisa O...
# 1    One by one, Juror #8 (Henry Fonda) convinces t...
# 2    James Cole’s (Bruce Willis’) memory/dream is o...
# 3    Academy Awards BEST PICTURE    Solomon Northup...
# 4    Aron Ralston (James Franco) goes hiking and cl...
# ..                                                 ...
# 991  After years of dead ends and even more terrori...
# 992  Robert Graysmith (Jake Gyllenhaal) concludes t...
# 993  On the way to Pacific Playland, which Columbus...
# 994  Zoolander  Derek (Ben Stiller) discovers that ...
# 995  Officer Judy Hopps (Ginniger Goodwin) discover...
#
# [996 rows x 3 columns]

# %% [markdown]
# Save as a file the Dataframe

# %%
from google.colab import files
df3.to_csv('Project_Dataset.csv', encoding='utf-8')
files.download('Project_Dataset.csv')
